# %%
import pandas as pd

# %%
from google.colab import files
arq = files.upload()
# Out:
#      <input type="file" id="files-b7718d43-88c7-4123-98c9-979218dd8210" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b7718d43-88c7-4123-98c9-979218dd8210">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hotel_bookings.csv to hotel_bookings.csv

# %%
df = pd.read_csv("hotel_bookings.csv")
df.head(3)
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2015-07-01
# 1  Resort Hotel            0  ...           Check-Out               2015-07-01
# 2  Resort Hotel            0  ...           Check-Out               2015-07-02
#
# [3 rows x 32 columns]

# %% [markdown]
# #Limpeza de Dados nulos

# %%
dg = df.isnull().sum()
dg
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# reservation_status_date                0
# dtype: int64

# %%
dh = (df['agent'].isnull().sum()) / len(df['hotel'])*100 
dh
# Out:
# 13.686238378423655

# %%
df.drop('agent', axis=1, inplace=True)

# %%
di = df.isnull().sum()
di
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# company                           112593
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# reservation_status_date                0
# dtype: int64

# %%
dj = (df['company'].isnull().sum()) / len(df['hotel'])*100
dj
# Out:
# 94.30689337465449

# %%
df.drop('company', axis=1, inplace=True)

# %%
dk = df.isnull().sum()
dk
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# arrival_date_year                   0
# arrival_date_month                  0
# arrival_date_week_number            0
# arrival_date_day_of_month           0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            4
# babies                              0
# meal                                0
# country                           488
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# days_in_waiting_list                0
# customer_type                       0
# adr                                 0
# required_car_parking_spaces         0
# total_of_special_requests           0
# reservation_status                  0
# reservation_status_date             0
# dtype: int64

# %%
dl = (df['country'].isnull().sum()) / len(df['hotel'])*100
dl
# Out:
# 0.40874445095904177

# %%
df.dropna(inplace=True)
df.head(3)
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2015-07-01
# 1  Resort Hotel            0  ...           Check-Out               2015-07-01
# 2  Resort Hotel            0  ...           Check-Out               2015-07-02
#
# [3 rows x 30 columns]

# %%
dm = df.isnull().sum()
dm
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# reservation_status                0
# reservation_status_date           0
# dtype: int64

# %% [markdown]
# Limpeza de dados nulos concluida
# #Redução de colunas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118898 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118898 non-null  object
#  1   is_canceled                     118898 non-null  int64
#  2   lead_time                       118898 non-null  int64
#  3   arrival_date_year               118898 non-null  int64
#  4   arrival_date_month              118898 non-null  object
#  5   arrival_date_week_number        118898 non-null  int64
#  6   arrival_date_day_of_month       118898 non-null  int64
#  7   stays_in_weekend_nights         118898 non-null  int64
#  8   stays_in_week_nights            118898 non-null  int64
#  9   adults                          118898 non-null  int64
#  10  children                        118898 non-null  float64
#  11  babies                          118898 non-null  int64
#  12  meal                            118898 non-null  object
#  13  country                         118898 non-null  object
#  14  market_segment                  118898 non-null  object
#  15  distribution_channel            118898 non-null  object
#  16  is_repeated_guest               118898 non-null  int64
#  17  previous_cancellations          118898 non-null  int64
#  18  previous_bookings_not_canceled  118898 non-null  int64
#  19  reserved_room_type              118898 non-null  object
#  20  assigned_room_type              118898 non-null  object
#  21  booking_changes                 118898 non-null  int64
#  22  deposit_type                    118898 non-null  object
#  23  days_in_waiting_list            118898 non-null  int64
#  24  customer_type                   118898 non-null  object
#  25  adr                             118898 non-null  float64
#  26  required_car_parking_spaces     118898 non-null  int64
#  27  total_of_special_requests       118898 non-null  int64
#  28  reservation_status              118898 non-null  object
#  29  reservation_status_date         118898 non-null  object
# dtypes: float64(2), int64(16), object(12)
# memory usage: 28.1+ MB

# %%
df['previous_bookings_not_canceled'].value_counts(normalize=True)*100
# Out:
# 0     97.142929
# 1      1.221215
# 2      0.450807
# 3      0.253158
# 4      0.175781
#         ...
# 47     0.000841
# 49     0.000841
# 50     0.000841
# 51     0.000841
# 72     0.000841
# Name: previous_bookings_not_canceled, Length: 73, dtype: float64

# %%
df['adults'].value_counts(normalize=True)*100
# Out:
# 2     75.270400
# 1     19.121432
# 3      5.212030
# 0      0.330535
# 4      0.052146
# 26     0.004205
# 27     0.001682
# 20     0.001682
# 5      0.001682
# 40     0.000841
# 50     0.000841
# 55     0.000841
# 6      0.000841
# 10     0.000841
# Name: adults, dtype: float64

# %%
df['babies'].value_counts(normalize=True)*100
# Out:
# 0     99.231274
# 1      0.755269
# 2      0.011775
# 10     0.000841
# 9      0.000841
# Name: babies, dtype: float64

# %%
df['children'].value_counts(normalize=True)*100
# Out:
# 0.0     92.784572
# 1.0      4.080809
# 2.0      3.069858
# 3.0      0.063920
# 10.0     0.000841
# Name: children, dtype: float64

# %%
dn = (df['country'].isnull().sum()) / len(df['hotel'])*100
dn
# Out:
# 0.0

# %%
df['is_repeated_guest'].value_counts(normalize=True)*100
# Out:
# 0    96.798937
# 1     3.201063
# Name: is_repeated_guest, dtype: float64

# %%
df['reserved_room_type'].value_counts(normalize=True)*100
# Out:
# A    71.995324
# D    16.125587
# E     5.464348
# F     2.430655
# G     1.751922
# B     0.936938
# C     0.783024
# H     0.505475
# L     0.005046
# P     0.001682
# Name: reserved_room_type, dtype: float64

# %%
df['assigned_room_type'].value_counts(normalize=True)*100
# Out:
# A    62.122996
# D    21.166041
# E     6.508099
# F     3.138825
# G     2.135444
# C     1.979848
# B     1.815842
# H     0.595468
# I     0.300257
# K     0.234655
# P     0.001682
# L     0.000841
# Name: assigned_room_type, dtype: float64

# %%
df['booking_changes'].value_counts(normalize=True)*100
# Out:
# 0     84.864337
# 1     10.630120
# 2      3.187606
# 3      0.777978
# 4      0.315396
# 5      0.099245
# 6      0.052987
# 7      0.026073
# 8      0.014298
# 9      0.006728
# 10     0.005046
# 13     0.004205
# 14     0.004205
# 15     0.002523
# 16     0.001682
# 17     0.001682
# 12     0.001682
# 11     0.001682
# 20     0.000841
# 21     0.000841
# 18     0.000841
# Name: booking_changes, dtype: float64

# %%
df['deposit_type'].value_counts(normalize=True)*100
# Out:
# No Deposit    87.607025
# Non Refund    12.256724
# Refundable     0.136251
# Name: deposit_type, dtype: float64

# %%
df['customer_type'].value_counts(normalize=True)*100
# Out:
# Transient          75.000421
# Transient-Party    21.092028
# Contract            3.428148
# Group               0.479403
# Name: customer_type, dtype: float64

# %%
df['required_car_parking_spaces'].value_counts(normalize=True)*100
# Out:
# 0    93.851873
# 1     6.120372
# 2     0.023550
# 3     0.002523
# 8     0.001682
# Name: required_car_parking_spaces, dtype: float64

# %%
df['adr'].value_counts(normalize=True)*100
# Out:
# 62.00     3.156487
# 75.00     2.279265
# 90.00     2.078252
# 65.00     2.016014
# 0.00      1.629969
#             ...
# 96.09     0.000841
# 48.03     0.000841
# 89.43     0.000841
# 63.07     0.000841
# 157.71    0.000841
# Name: adr, Length: 8870, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118898 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118898 non-null  object
#  1   is_canceled                     118898 non-null  int64
#  2   lead_time                       118898 non-null  int64
#  3   arrival_date_year               118898 non-null  int64
#  4   arrival_date_month              118898 non-null  object
#  5   arrival_date_week_number        118898 non-null  int64
#  6   arrival_date_day_of_month       118898 non-null  int64
#  7   stays_in_weekend_nights         118898 non-null  int64
#  8   stays_in_week_nights            118898 non-null  int64
#  9   adults                          118898 non-null  int64
#  10  children                        118898 non-null  float64
#  11  babies                          118898 non-null  int64
#  12  meal                            118898 non-null  object
#  13  country                         118898 non-null  object
#  14  market_segment                  118898 non-null  object
#  15  distribution_channel            118898 non-null  object
#  16  is_repeated_guest               118898 non-null  int64
#  17  previous_cancellations          118898 non-null  int64
#  18  previous_bookings_not_canceled  118898 non-null  int64
#  19  reserved_room_type              118898 non-null  object
#  20  assigned_room_type              118898 non-null  object
#  21  booking_changes                 118898 non-null  int64
#  22  deposit_type                    118898 non-null  object
#  23  days_in_waiting_list            118898 non-null  int64
#  24  customer_type                   118898 non-null  object
#  25  adr                             118898 non-null  float64
#  26  required_car_parking_spaces     118898 non-null  int64
#  27  total_of_special_requests       118898 non-null  int64
#  28  reservation_status              118898 non-null  object
#  29  reservation_status_date         118898 non-null  object
# dtypes: float64(2), int64(16), object(12)
# memory usage: 28.1+ MB

# %%
df.head(3)
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2015-07-01
# 1  Resort Hotel            0  ...           Check-Out               2015-07-01
# 2  Resort Hotel            0  ...           Check-Out               2015-07-02
#
# [3 rows x 30 columns]

# %% [markdown]
# #Abaixo colunas excluídas conforme descrito em readme.me

# %%
df.drop(['arrival_date_week_number', 'children', 'babies', 'previous_cancellations', 'previous_bookings_not_canceled', 'days_in_waiting_list', 'total_of_special_requests', 'reservation_status', 'reservation_status_date'], axis=1, inplace=True)
df.head(5)
# Out:
#           hotel  is_canceled  ...   adr  required_car_parking_spaces
# 0  Resort Hotel            0  ...   0.0                            0
# 1  Resort Hotel            0  ...   0.0                            0
# 2  Resort Hotel            0  ...  75.0                            0
# 3  Resort Hotel            0  ...  75.0                            0
# 4  Resort Hotel            0  ...  98.0                            0
#
# [5 rows x 21 columns]

# %%
df.to_csv("hotel_bookings_limpo.csv", index=False)

# %%
dd = pd.read_csv("hotel_bookings_limpo.csv")
dd.head(3)
# Out:
#           hotel  is_canceled  ...   adr  required_car_parking_spaces
# 0  Resort Hotel            0  ...   0.0                            0
# 1  Resort Hotel            0  ...   0.0                            0
# 2  Resort Hotel            0  ...  75.0                            0
#
# [3 rows x 21 columns]
