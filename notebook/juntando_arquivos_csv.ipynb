# %%
#Importando a biblioteca
import pandas as pd

# %%
#Upload do arquivo
from google.colab import files
arq = files.upload()
# Out:
#      <input type="file" id="files-ae175b8a-05b7-4008-beeb-93e98c6a55d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae175b8a-05b7-4008-beeb-93e98c6a55d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hotel_bookings_2015.csv to hotel_bookings_2015 (1).csv
# Saving hotel_bookings_2016.csv to hotel_bookings_2016.csv
# Saving hotel_bookings_2017.csv to hotel_bookings_2017.csv

# %%
df1 = pd.read_csv('hotel_bookings_2015.csv')
df2 = pd.read_csv('hotel_bookings_2016.csv')
df3 = pd.read_csv('hotel_bookings_2017.csv')

# %%
df1.head(3)
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2015-07-01
# 1  Resort Hotel            0  ...           Check-Out               2015-07-01
# 2  Resort Hotel            0  ...           Check-Out               2015-07-02
#
# [3 rows x 32 columns]

# %%
df2.head(3)
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2016-01-02
# 1  Resort Hotel            0  ...           Check-Out               2016-01-02
# 2  Resort Hotel            1  ...             No-Show               2016-01-01
#
# [3 rows x 32 columns]

# %%
df3.head(3)
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            1  ...            Canceled               2016-10-20
# 1  Resort Hotel            1  ...            Canceled               2016-12-04
# 2  Resort Hotel            1  ...            Canceled               2016-11-11
#
# [3 rows x 32 columns]

# %%
#juntando todos os arquivos
df = pd.concat([df1,df2,df3])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119390 entries, 0 to 40686
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...
